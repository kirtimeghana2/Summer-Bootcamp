# %%
import os
os.getcwd()
# Out:
# 'D:\\Sharda academic files\\Bootcamp\\Technicals\\Myproject'

# %%
import pandas as pd
import numpy as np

# %%
#loading the dataset
data = pd.read_csv('ElectricVehicle.csv', low_memory=False)
data.head()
# Out:
#    VIN (1-10)     County       City State  Postal Code  Model Year   Make  \
# 0  5YJYGDEE1L       King    Seattle    WA      98122.0        2020  TESLA
# 1  7SAYGDEE9P  Snohomish    Bothell    WA      98021.0        2023  TESLA
# 2  5YJSA1E4XK       King    Seattle    WA      98109.0        2019  TESLA
# 3  5YJSA1E27G       King   Issaquah    WA      98027.0        2016  TESLA
# 4  5YJYGDEE5M     Kitsap  Suquamish    WA      98392.0        2021    NaN
#
#      Model           Electric Vehicle Type  \
# 0  MODEL Y  Battery Electric Vehicle (BEV)
# 1  MODEL Y  Battery Electric Vehicle (BEV)
# 2  MODEL S  Battery Electric Vehicle (BEV)
# 3  MODEL S  Battery Electric Vehicle (BEV)
# 4  MODEL Y  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible            291
# 1  Eligibility unknown as battery range has not b...              0
# 2                                                NaN            270
# 3            Clean Alternative Fuel Vehicle Eligible            210
# 4  Eligibility unknown as battery range has not b...              0
#
#    Base MSRP Legislative District  DOL Vehicle ID  \
# 0          0                   37       125701579
# 1          0                    1       244285107
# 2          0                   36       156773144
# 3          0                    5       165103011
# 4          0                   23       205138552
#
#                 Vehicle Location  \
# 0   POINT (-122.30839 47.610365)
# 1  POINT (-122.179458 47.802589)
# 2   POINT (-122.34848 47.632405)
# 3   POINT (-122.03646 47.534065)
# 4   POINT (-122.55717 47.733415)
#
#                                 Electric Utility  2020 Census Tract
# 0   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 1                         PUGET SOUND ENERGY INC       5.306105e+10
# 2   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 3  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 4                         PUGET SOUND ENERGY INC       5.303594e+10

# %%
# 1. Display the top 5 rows
top_5_rows = data.head()
print("Top 5 rows of the dataset:")
print(top_5_rows)
# Out:
# Top 5 rows of the dataset:
#    VIN (1-10)     County       City State  Postal Code  Model Year   Make  \
# 0  5YJYGDEE1L       King    Seattle    WA      98122.0        2020  TESLA
# 1  7SAYGDEE9P  Snohomish    Bothell    WA      98021.0        2023  TESLA
# 2  5YJSA1E4XK       King    Seattle    WA      98109.0        2019  TESLA
# 3  5YJSA1E27G       King   Issaquah    WA      98027.0        2016  TESLA
# 4  5YJYGDEE5M     Kitsap  Suquamish    WA      98392.0        2021    NaN
#
#      Model           Electric Vehicle Type  \
# 0  MODEL Y  Battery Electric Vehicle (BEV)
# 1  MODEL Y  Battery Electric Vehicle (BEV)
# 2  MODEL S  Battery Electric Vehicle (BEV)
# 3  MODEL S  Battery Electric Vehicle (BEV)
# 4  MODEL Y  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible            291
# 1  Eligibility unknown as battery range has not b...              0
# 2                                                NaN            270
# 3            Clean Alternative Fuel Vehicle Eligible            210
# 4  Eligibility unknown as battery range has not b...              0
#
#    Base MSRP Legislative District  DOL Vehicle ID  \
# 0          0                   37       125701579
# 1          0                    1       244285107
# 2          0                   36       156773144
# 3          0                    5       165103011
# 4          0                   23       205138552
#
#                 Vehicle Location  \
# 0   POINT (-122.30839 47.610365)
# 1  POINT (-122.179458 47.802589)
# 2   POINT (-122.34848 47.632405)
# 3   POINT (-122.03646 47.534065)
# 4   POINT (-122.55717 47.733415)
#
#                                 Electric Utility  2020 Census Tract
# 0   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 1                         PUGET SOUND ENERGY INC       5.306105e+10
# 2   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 3  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 4                         PUGET SOUND ENERGY INC       5.303594e+10

# %%
# 2. Display the last 5 rows
last_5_rows = data.tail()
print("\nLast 5 rows of the dataset:")
print(last_5_rows)
# Out:
# Last 5 rows of the dataset:
#         VIN (1-10)  County           City State  Postal Code  Model Year  \
# 177861  7SAYGDEE3N  Pierce    Bonney Lake    WA      98391.0        2022
# 177862  KM8K23AG1P   Mason        Shelton    WA      98584.0        2023
# 177863  5YJYGDEE6M   Grant         Quincy    WA      98848.0        2021
# 177864  WVGKMPE27M    King  Black Diamond    WA      98010.0        2021
# 177865  5YJ3E1EA8M  Pierce         Tacoma    WA      98422.0        2021
#
#               Make          Model           Electric Vehicle Type  \
# 177861       TESLA        MODEL Y  Battery Electric Vehicle (BEV)
# 177862     HYUNDAI  KONA ELECTRIC  Battery Electric Vehicle (BEV)
# 177863       TESLA        MODEL Y  Battery Electric Vehicle (BEV)
# 177864  VOLKSWAGEN           ID.4  Battery Electric Vehicle (BEV)
# 177865       TESLA        MODEL 3  Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility Electric Range  \
# 177861  Eligibility unknown as battery range has not b...              0
# 177862  Eligibility unknown as battery range has not b...              0
# 177863  Eligibility unknown as battery range has not b...              0
# 177864  Eligibility unknown as battery range has not b...              0
# 177865  Eligibility unknown as battery range has not b...              0
#
#         Base MSRP Legislative District  DOL Vehicle ID  \
# 177861          0                   31       195224452
# 177862          0                   35       228454180
# 177863          0                   13       168797219
# 177864          0                    5       182448801
# 177865          0                   27       211464683
#
#                        Vehicle Location  \
# 177861     POINT (-122.183805 47.18062)
# 177862    POINT (-123.105305 47.211085)
# 177863  POINT (-119.8493873 47.2339933)
# 177864     POINT (-122.00451 47.312185)
# 177865      POINT (-122.38578 47.28971)
#
#                                          Electric Utility  2020 Census Tract
# 177861      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.305307e+10
# 177862  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.304596e+10
# 177863                           PUD NO 2 OF GRANT COUNTY       5.302501e+10
# 177864      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 177865  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305394e+10

# %%
# 3. Check the shape of the dataset
shape = data.shape
print("\nShape of the dataset:", shape)
# Out:
# Shape of the dataset: (177866, 17)

# %%
# 4. Check the datatypes of each feature
datatypes = data.dtypes
print("\nDatatypes of each feature:")
print(datatypes)
# Out:
# Datatypes of each feature:
# VIN (1-10)                                            object
# County                                                object
# City                                                  object
# State                                                 object
# Postal Code                                          float64
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                        object
# Base MSRP                                              int64
# Legislative District                                  object
# DOL Vehicle ID                                         int64
# Vehicle Location                                      object
# Electric Utility                                      object
# 2020 Census Tract                                    float64
# dtype: object

# %%
# 5. Check the Statistical summary
stat_summary = data.describe()
print("\nStatistical summary of the dataset:")
print(stat_summary)
# Out:
# Statistical summary of the dataset:
#          Postal Code     Model Year      Base MSRP  DOL Vehicle ID  \
# count  177861.000000  177866.000000  177866.000000    1.778660e+05
# mean    98172.453506    2020.515512    1073.109363    2.202313e+08
# std      2442.450668       2.989384    8358.624956    7.584987e+07
# min      1545.000000    1997.000000       0.000000    4.385000e+03
# 25%     98052.000000    2019.000000       0.000000    1.814743e+08
# 50%     98122.000000    2022.000000       0.000000    2.282522e+08
# 75%     98370.000000    2023.000000       0.000000    2.548445e+08
# max     99577.000000    2024.000000  845000.000000    4.792548e+08
#
#        2020 Census Tract
# count       1.778610e+05
# mean        5.297672e+10
# std         1.578047e+09
# min         1.001020e+09
# 25%         5.303301e+10
# 50%         5.303303e+10
# 75%         5.305307e+10
# max         5.603300e+10

# %%
# 6. Check the null values
null_values = data.isnull().sum()
print("\nNull values in each column:")
print(null_values)
# Out:
# Null values in each column:
# VIN (1-10)                                             0
# County                                                 5
# City                                                   5
# State                                                  0
# Postal Code                                            5
# Model Year                                             0
# Make                                                   7
# Model                                                  4
# Electric Vehicle Type                                  6
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      2
# Electric Range                                         3
# Base MSRP                                              0
# Legislative District                                 389
# DOL Vehicle ID                                         0
# Vehicle Location                                       9
# Electric Utility                                       5
# 2020 Census Tract                                      5
# dtype: int64

# %%
# 7. Check the duplicate values
duplicate_values = data.duplicated().sum()
print("\nNumber of duplicate rows:", duplicate_values)
# Out:
# Number of duplicate rows: 0

# %%
# Converting some columns to numeric to avoid errors
data['Model Year'] = pd.to_numeric(data['Model Year'], errors='coerce')
data['Electric Range'] = pd.to_numeric(data['Electric Range'], errors='coerce')
data['Base MSRP'] = pd.to_numeric(data['Base MSRP'], errors='coerce')

# %%
# 8. Check for anomalies or wrong entries
anomalies = data[(data['Model Year'] > 2024) | (data['Electric Range'] < 0) | (data['Base MSRP'] < 0)]
print("\nPotential anomalies or wrong entries:")
print(anomalies)
# Out:
# Potential anomalies or wrong entries:
# Empty DataFrame
# Columns: [VIN (1-10), County, City, State, Postal Code, Model Year, Make, Model, Electric Vehicle Type, Clean Alternative Fuel Vehicle (CAFV) Eligibility, Electric Range, Base MSRP, Legislative District, DOL Vehicle ID, Vehicle Location, Electric Utility, 2020 Census Tract]
# Index: []

# %%
# 9. Check the outliers using a more memory-efficient approach
outliers = pd.DataFrame()

for column in data.select_dtypes(include=[np.number]).columns:
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    column_outliers = data[(data[column] < (Q1 - 1.5 * IQR)) | (data[column] > (Q3 + 1.5 * IQR))]
    outliers = pd.concat([outliers, column_outliers])

outliers.drop_duplicates(inplace=True)
print("\nOutliers in the dataset:")
print(outliers)
# Out:
# Outliers in the dataset:
#         VIN (1-10)    County        City State  Postal Code  Model Year  \
# 6       1N4AZ0CP2D    Yakima      Yakima    WA      98903.0        2013
# 12      1G1FZ6S07M    Yakima      Yakima    WA      98908.0        2021
# 19      5YJ3E1EA5K    Yakima      Yakima    WA      98903.0        2019
# 22      1FADP5CUXD    Yakima      Yakima    WA      98902.0        2013
# 44      KNDRMDLH4P    Yakima      Yakima    WA      98908.0        2023
# ...            ...       ...         ...   ...          ...         ...
# 177687  JTDKARFP7K  Thurston     Olympia    WA      98502.0        2019
# 177715  1N4BZ1CP0K   Whatcom  Bellingham    WA      98225.0        2019
# 177752  3FA6P0PU2H  Thurston     Olympia    WA      98512.0        2017
# 177776  1N4AZ1CP9J   Whatcom    Ferndale    WA      98248.0        2018
# 177848  KNDCC3LD1K   Clallam      Sequim    WA      98382.0        2019
#
#              Make        Model                   Electric Vehicle Type  \
# 6          NISSAN         LEAF          Battery Electric Vehicle (BEV)
# 12      CHEVROLET      BOLT EV          Battery Electric Vehicle (BEV)
# 19          TESLA      MODEL 3                                     NaN
# 22           FORD        C-MAX  Plug-in Hybrid Electric Vehicle (PHEV)
# 44            KIA      SORENTO  Plug-in Hybrid Electric Vehicle (PHEV)
# ...           ...          ...                                     ...
# 177687     TOYOTA  PRIUS PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 177715     NISSAN         LEAF          Battery Electric Vehicle (BEV)
# 177752       FORD       FUSION  Plug-in Hybrid Electric Vehicle (PHEV)
# 177776     NISSAN         LEAF          Battery Electric Vehicle (BEV)
# 177848        KIA         NIRO  Plug-in Hybrid Electric Vehicle (PHEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 6                 Clean Alternative Fuel Vehicle Eligible            75.0
# 12      Eligibility unknown as battery range has not b...             0.0
# 19                Clean Alternative Fuel Vehicle Eligible           220.0
# 22                  Not eligible due to low battery range            19.0
# 44                Clean Alternative Fuel Vehicle Eligible            32.0
# ...                                                   ...             ...
# 177687              Not eligible due to low battery range            25.0
# 177715            Clean Alternative Fuel Vehicle Eligible           150.0
# 177752              Not eligible due to low battery range            21.0
# 177776            Clean Alternative Fuel Vehicle Eligible           151.0
# 177848              Not eligible due to low battery range            26.0
#
#         Base MSRP Legislative District  DOL Vehicle ID  \
# 6               0                    ?       150126840
# 12              0                   14       156686106
# 19              0                   14       198205521
# 22              0                   14       132294879
# 44              0                   14       245761666
# ...           ...                  ...             ...
# 177687          0                   22       476626013
# 177715          0                   40       477314127
# 177752          0                   35         5000075
# 177776          0                   42       474163553
# 177848          0                   24       474036790
#
#                        Vehicle Location  \
# 6         POINT (-120.477805 46.553505)
# 12      POINT (-120.6027202 46.5965625)
# 19        POINT (-120.477805 46.553505)
# 22       POINT (-120.524012 46.5973939)
# 44      POINT (-120.6027202 46.5965625)
# ...                                 ...
# 177687     POINT (-122.92145 47.045935)
# 177715    POINT (-122.486115 48.761615)
# 177752  POINT (-122.9131017 47.0135926)
# 177776    POINT (-122.6011039 48.85324)
# 177848     POINT (-123.105015 48.08125)
#
#                                          Electric Utility  2020 Census Tract
# 6                                              PACIFICORP       5.307700e+10
# 12                                             PACIFICORP       5.307700e+10
# 19                                             PACIFICORP       5.307700e+10
# 22                                             PACIFICORP       5.307700e+10
# 44                                             PACIFICORP       5.307700e+10
# ...                                                   ...                ...
# 177687                             PUGET SOUND ENERGY INC       5.306701e+10
# 177715  PUGET SOUND ENERGY INC||PUD NO 1 OF WHATCOM CO...       5.307300e+10
# 177752                             PUGET SOUND ENERGY INC       5.306701e+10
# 177776  PUGET SOUND ENERGY INC||PUD NO 1 OF WHATCOM CO...       5.307301e+10
# 177848  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...       5.300900e+10
#
# [48691 rows x 17 columns]

# %%
#10 Vehicle Location Analysis

import pandas as pd


def clean_data(data, outliers=None):

    cleaned_data = data.copy()  # Operate on a copy to avoid modifying original data

    # Drop duplicates
    cleaned_data = cleaned_data.drop_duplicates()

    # Drop unnecessary columns
    columns_to_drop = ['VIN (1-10)', 'DOL Vehicle ID']
    cleaned_data = cleaned_data.drop(columns=columns_to_drop, errors='ignore')

    # Impute null values using a function for clarity
    def impute_nulls(df):
        for col in df.columns:
            if df[col].isnull().sum() > 0:
                if pd.api.types.is_numeric_dtype(df[col]):
                    df[col].fillna(df[col].median(), inplace=False)  # Removed inplace=True
                else:
                    df[col].fillna(df[col].mode()[0], inplace=False)  # Removed inplace=True
        return df

    cleaned_data = impute_nulls(cleaned_data)

    # Outlier treatment (assuming you have identified outliers)
    if outliers is not None:
        cleaned_data = cleaned_data.loc[~cleaned_data.index.isin(outliers)]

    return cleaned_data


# Assuming you have your data loaded into a DataFrame named 'data'
cleaned_data = clean_data(data)

print("\nData after cleaning:")
print(cleaned_data.head())
print("\nShape of cleaned dataset:", cleaned_data.shape)
# Out:
# Data after cleaning:
#       County       City State  Postal Code  Model Year   Make    Model  \
# 0       King    Seattle    WA      98122.0        2020  TESLA  MODEL Y
# 1  Snohomish    Bothell    WA      98021.0        2023  TESLA  MODEL Y
# 2       King    Seattle    WA      98109.0        2019  TESLA  MODEL S
# 3       King   Issaquah    WA      98027.0        2016  TESLA  MODEL S
# 4     Kitsap  Suquamish    WA      98392.0        2021    NaN  MODEL Y
#
#             Electric Vehicle Type  \
# 0  Battery Electric Vehicle (BEV)
# 1  Battery Electric Vehicle (BEV)
# 2  Battery Electric Vehicle (BEV)
# 3  Battery Electric Vehicle (BEV)
# 4  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible           291.0
# 1  Eligibility unknown as battery range has not b...             0.0
# 2                                                NaN           270.0
# 3            Clean Alternative Fuel Vehicle Eligible           210.0
# 4  Eligibility unknown as battery range has not b...             0.0
#
#    Base MSRP Legislative District               Vehicle Location  \
# 0          0                   37   POINT (-122.30839 47.610365)
# 1          0                    1  POINT (-122.179458 47.802589)
# 2          0                   36   POINT (-122.34848 47.632405)
# 3          0                    5   POINT (-122.03646 47.534065)
# 4          0                   23   POINT (-122.55717 47.733415)
#
#                                 Electric Utility  2020 Census Tract
# 0   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 1                         PUGET SOUND ENERGY INC       5.306105e+10
# 2   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 3  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 4                         PUGET SOUND ENERGY INC       5.303594e+10
#
# Shape of cleaned dataset: (177866, 15)

# %%
#1 Desciptive Statictics
# Calculating mean, median, and standard deviation of Base MSRP
mean_msrp = data['Base MSRP'].mean()
median_msrp = data['Base MSRP'].median()
std_dev_msrp = data['Base MSRP'].std()

print(f"Mean Base MSRP: ${mean_msrp:.2f}")
print(f"Median Base MSRP: ${median_msrp:.2f}")
print(f"Standard Deviation of Base MSRP: ${std_dev_msrp:.2f}")
# Out:
# Mean Base MSRP: $1073.11
# Median Base MSRP: $0.00
# Standard Deviation of Base MSRP: $8358.62

# %% [markdown]
# #2 Data Distribution
# import matplotlib.pyplot as plt
#
# # Count the number of vehicles for each make
# make_counts = data['Make'].value_counts()
#
# # Plotting the bar chart
# plt.figure(figsize=(12, 6))
# make_counts.plot(kind='bar')
# plt.title('Distribution of Vehicle Makes')
# plt.xlabel('Make')
# plt.ylabel('Count')
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()

# %%
#2 Data distribution using a bar chart

import matplotlib.pyplot as plt
import seaborn as sns  

plt.figure(figsize=(12, 8))  
sns.kdeplot(data['Postal Code'], fill=True, cmap='viridis', bw_adjust=0.5)  
plt.title('Density Plot of Vehicles Across Postal Codes')
plt.xlabel('Postal Code')
plt.ylabel('Density')
plt.tight_layout()
plt.show()

# %%
#3 Model Year Analysis:

# Frequency table
model_year_counts = data['Model Year'].value_counts()
print(model_year_counts)

# Histogram
plt.figure(figsize=(10, 6))
data['Model Year'].hist(bins=20)  # Adjust bins as needed
plt.title("Frequency of Model Years")
plt.xlabel("Model Year")
plt.ylabel("Count")
plt.show()
# Out:
# Model Year
# 2023    57587
# 2022    27776
# 2021    19132
# 2018    14323
# 2020    11768
# 2019    10940
# 2017     8562
# 2024     7080
# 2016     5483
# 2015     4844
# 2013     4409
# 2014     3509
# 2012     1618
# 2011      775
# 2010       23
# 2008       20
# 2000        7
# 1999        5
# 2002        2
# 1998        1
# 1997        1
# 2003        1
# Name: count, dtype: int64

# %%
#4. Electric Vehicle Type:

electric_type_counts = data['Electric Vehicle Type'].value_counts(normalize=True)

if 'BEV' in electric_type_counts:
    bev_proportion = electric_type_counts['BEV'] * 100
    print(f"Proportion of BEVs: {bev_proportion:.2f}%")
else:
    print("No Battery Electric Vehicles (BEVs) found in the dataset.")
# Out:
# No Battery Electric Vehicles (BEVs) found in the dataset.

# %%
#5 Electric range analysis
# Average electric range for different makes
avg_range_by_make = data.groupby('Make')['Electric Range'].mean().sort_values(ascending=False)

print("Average Electric Range for Vehicles of Different Makes:")
print(avg_range_by_make)
# Out:
# Average Electric Range for Vehicles of Different Makes:
# Make
# JAGUAR                  203.741379
# BMW                     201.159730
# WHEEGO ELECTRIC CARS    100.000000
# TH!NK                   100.000000
# CHEVROLET                94.552785
# FIAT                     85.645408
# NISSAN                   80.348053
# TESLA                    77.341268
# SMART                    62.325926
# AZURE DYNAMICS           56.000000
# AUDI                     50.984641
# HONDA                    46.600240
# PORSCHE                  44.812116
# KIA                      44.650161
# POLESTAR                 37.776644
# ALFA ROMEO               33.000000
# CHRYSLER                 32.212162
# DODGE                    32.000000
# MITSUBISHI               30.646138
# TOYOTA                   28.095102
# MAZDA                    25.781513
# LAND ROVER               25.000000
# LINCOLN                  23.543071
# VOLKSWAGEN               22.927058
# JEEP                     22.365402
# BENTLEY                  19.666667
# HYUNDAI                  19.362914
# LEXUS                    18.800000
# MINI                     18.036789
# VOLVO                    16.135737
# FORD                     10.812914
# MERCEDES-BENZ             9.346130
# CADILLAC                  8.798429
# FISKER                    8.755102
# SUBARU                    1.350181
# RIVIAN                    0.000000
# ROLLS ROYCE               0.000000
# LUCID                     0.000000
# GENESIS                   0.000000
# GMC                       0.000000
# Name: Electric Range, dtype: float64

# %%
#6 County distribution
# Count vehicles per county
county_counts = data['County'].value_counts()

# Plotting pie chart
plt.figure(figsize=(10, 8))
plt.pie(county_counts, labels=county_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Vehicles Across Counties in Washington State')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.tight_layout()
plt.show()

# %%
# 7. Price analysis
# Assuming 'Clean Alternative Fuel Vehicle (CAFV) Eligibility' is a column indicating eligibility status

# Filter data for CAFV eligible and not eligible vehicles
cafv_eligible_data = data[data['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] == 'Clean Alternative Fuel Vehicle Eligible']
cafv_not_eligible_data = data[data['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] != 'Clean Alternative Fuel Vehicle Eligible']

# Calculate average MSRP
avg_msrp_cafv_eligible = cafv_eligible_data['Base MSRP'].mean()
avg_msrp_not_cafv_eligible = cafv_not_eligible_data['Base MSRP'].mean()

print(f"Average Base MSRP for vehicles eligible for CAFV: ${avg_msrp_cafv_eligible:.2f}")
print(f"Average Base MSRP for vehicles not eligible for CAFV: ${avg_msrp_not_cafv_eligible:.2f}")
# Out:
# Average Base MSRP for vehicles eligible for CAFV: $2028.13
# Average Base MSRP for vehicles not eligible for CAFV: $505.16

# %%
#8 Geographical analysis
# Assuming 'City' is a column indicating city names
avg_msrp_by_city = data.groupby('City')['Base MSRP'].mean().sort_values(ascending=False)

print("Average Base MSRP Across Different Cities in Washington State:")
print(avg_msrp_by_city)
# Out:
# Average Base MSRP Across Different Cities in Washington State:
# City
# Hughesville    102000.0
# Indio           69900.0
# Mckinney        69900.0
# Leander         59900.0
# Portland        45350.0
#                  ...
# Lacrosse            0.0
# La Vernia           0.0
# La Mesa             0.0
# Klickitat           0.0
# Marina              0.0
# Name: Base MSRP, Length: 723, dtype: float64

# %%
#9 Legislative Districts
# Count vehicles per legislative district
legislative_district_counts = data['Legislative District'].value_counts()

# Display top legislative districts with highest number of registered electric vehicles
top_legislative_districts = legislative_district_counts.head(10)
print("Top 10 Legislative Districts with Highest Number of Registered Electric Vehicles:")
print(top_legislative_districts)
# Out:
# Top 10 Legislative Districts with Highest Number of Registered Electric Vehicles:
# Legislative District
# 41    11553
# 45    10737
# 48     9817
# 1      7786
# 5      7614
# 11     7507
# 36     7389
# 46     6901
# 43     6524
# 37     5215
# Name: count, dtype: int64

# %%
# 10. Electric utility providers
# Count vehicles per electric utility provider
electric_provider_counts = data['Electric Utility'].value_counts()

print("Distribution of Electric Utility Service Providers:")
print(electric_provider_counts)
# Out:
# Distribution of Electric Utility Service Providers:
# Electric Utility
# PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)                                               65990
# PUGET SOUND ENERGY INC                                                                      35882
# CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)                                                31381
# BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)                            10173
# BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PENINSULA LIGHT COMPANY              7828
#                                                                                             ...
# BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF ASOTIN COUNTY||INLAND POWER & LIGHT COMPANY        2
# BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLALLAM COUNTY|PUD NO 1 OF JEFFERSON COUNTY        1
# BONNEVILLE POWER ADMINISTRATION||PENINSULA LIGHT COMPANY                                        1
# CITY OF SEATTLE - (WA)                                                                          1
# BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF JEFFERSON COUNTY                                   1
# Name: count, Length: 76, dtype: int64

# %%
#11 Census Tract Analysis
# Count vehicles per census tract
census_tract_counts = data['2020 Census Tract'].value_counts()

# Display insights based on vehicle counts per tract
print("Vehicle Counts per 2020 Census Tract:")
print(census_tract_counts)
# Out:
# Vehicle Counts per 2020 Census Tract:
# 2020 Census Tract
# 5.303303e+10    2479
# 5.303303e+10     983
# 5.303303e+10     820
# 5.303303e+10     801
# 5.306701e+10     672
#                 ...
# 4.903511e+10       1
# 6.111008e+09       1
# 1.703181e+10       1
# 4.204101e+10       1
# 2.109300e+10       1
# Name: count, Length: 2115, dtype: int64

# %%
#12 Electric range correlation
# Calculate correlation coefficient 
correlation_coefficient = data['Electric Range'].corr(data['Base MSRP'])

print(f"Correlation Coefficient between Electric Range and Base MSRP: {correlation_coefficient:.2f}")
# Interpret the result based on the coefficient value (positive or negative correlation)
# Out:
# Correlation Coefficient between Electric Range and Base MSRP: 0.00

# %%
#13 VIN analysis
# Analyze VIN (1-10) for patterns or common prefixes/suffixes
vin_patterns = data['VIN (1-10)'].str[:3].value_counts()

print("Most Common VIN Prefixes (First 3 characters):")
print(vin_patterns.head())
# Out:
# Most Common VIN Prefixes (First 3 characters):
# VIN (1-10)
# 5YJ    50385
# 7SA    29274
# 1G1    13389
# 1N4    12120
# KND     7325
# Name: count, dtype: int64

# %%
# 14 Eligibility status

eligible_cafv = data['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].str.contains('Eligible', na=False)
percentage_cafv_eligible = (eligible_cafv.mean()) * 100

print(f"Percentage of Vehicles Eligible for CAFV Program: {percentage_cafv_eligible:.2f}%")
# Out:
# Percentage of Vehicles Eligible for CAFV Program: 37.29%

# %%
#15 Model Popularity
# Frequency table of top 10 vehicle models
top_models = data['Model'].value_counts().head(10)

print("Top 10 Most Popular Vehicle Models:")
print(top_models)
# Out:
# Top 10 Most Popular Vehicle Models:
# Model
# MODEL Y           35989
# MODEL 3           30091
# LEAF              13365
# MODEL S            7734
# BOLT EV            6821
# MODEL X            5796
# VOLT               4796
# ID.4               3937
# WRANGLER           3392
# MUSTANG MACH-E     3322
# Name: count, dtype: int64

# %%
#16 Postal Code Distribution

import matplotlib.pyplot as plt
import seaborn as sns  

plt.figure(figsize=(12, 8))
sns.kdeplot(data['Postal Code'], fill=True, cmap='viridis', bw_adjust=0.5)
plt.title('Density Plot of Vehicles Across Postal Codes')
plt.xlabel('Postal Code')
plt.ylabel('Density')
plt.tight_layout()
plt.show()

# %%
#17 Fetch the location details of any 5 vehicles
import pandas as pd

# Extract desired columns
location_data = data[['City', 'State', 'Postal Code']]

print(location_data.head())
# Out:
#         City State  Postal Code
# 0    Seattle    WA      98122.0
# 1    Bothell    WA      98021.0
# 2    Seattle    WA      98109.0
# 3   Issaquah    WA      98027.0
# 4  Suquamish    WA      98392.0

# %%
#18 Model Year Trend
# Count of registered electric vehicles by model year
yearly_counts = data['Model Year'].value_counts().sort_index()

plt.figure(figsize=(12, 6))
plt.plot(yearly_counts.index, yearly_counts.values, marker='o')
plt.title('Trend in Number of Registered Electric Vehicles by Model Year')
plt.xlabel('Model Year')
plt.ylabel('Number of Vehicles')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#19 Range vs. Year
plt.figure(figsize=(10, 8)) 
plt.scatter(data['Model Year'], data['Electric Range'], alpha=0.5, c='g', edgecolors='k')
plt.title('Electric Range vs. Model Year')
plt.xlabel('Model Year')
plt.ylabel('Electric Range (miles)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#20 Legislative District and MSRP
# Assuming 'Legislative District' is a column indicating legislative districts
avg_msrp_by_district = data.groupby('Legislative District')['Base MSRP'].mean().sort_values(ascending=False)

print("Average Base MSRP Across Different Legislative Districts:")
print(avg_msrp_by_district)
# Out:
# Average Base MSRP Across Different Legislative Districts:
# Legislative District
# 29    1715.984784
# 15    1715.677201
# 48    1429.105124
# 40    1420.897841
# 23    1420.398172
# 25    1414.766050
# 16    1334.344633
# 41    1297.992729
# 19    1290.935078
# 12    1278.880779
# 4     1257.040816
# 42    1250.885843
# 10    1245.738900
# 35    1243.739952
# 26    1224.790842
# 45    1194.102636
# 21    1178.103175
# 28    1146.963109
# 20    1133.941214
# 39    1131.482838
# 37    1117.395014
# 13    1088.637490
# 2     1087.285360
# 30    1084.551887
# 43    1069.052728
# 46    1067.936531
# 44    1061.381227
# 34    1054.724539
# 27    1054.357653
# 5     1049.491069
# 49    1005.100418
# 38    1000.397465
# 17     996.523333
# 8      968.943200
# 31     966.738710
# 6      965.044352
# 18     952.116358
# 36     931.807416
# 47     924.842105
# 32     871.715236
# 3      867.345890
# 1      840.005780
# 24     770.614806
# 9      698.793619
# 22     690.458059
# 33     672.292958
# 14     644.514260
# 7      577.943981
# 11     461.154922
# ?        0.000000
# Name: Base MSRP, dtype: float64

# %%
print(data.columns)
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')
